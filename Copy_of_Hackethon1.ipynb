# %% [markdown]
# <a href="https://colab.research.google.com/github/nishkarsh-coder/pepcodig_hackethon/blob/main/Copy_of_Hackethon1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
train= pd.read_csv("/content/drive/MyDrive/Copy of train_file.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
test=pd.read_csv("/content/drive/MyDrive/Copy of test_file.csv")

# %%
train.head(2)
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    35342-20020816     1256593           32811            1
# 1  1358463-20051116     1639294          262311           29
#
#             LEGAL NAME DOING BUSINESS AS NAME                     ADDRESS  \
# 0         CARMEN CAHUE  CLAUDIA'S BRIDAL SHOP  2625 S CENTRAL PARK AVE  1
# 1  ISLA TROPICAL, INC.          ISLA TROPICAL         2825 W MONTROSE AVE
#
#       CITY STATE ZIP CODE  ...  LICENSE TERM START DATE  \
# 0  CHICAGO    IL  60623.0  ...      2002-08-16T00:00:00
# 1  CHICAGO    IL    60618  ...      2005-11-16T00:00:00
#
#    LICENSE TERM EXPIRATION DATE LICENSE APPROVED FOR ISSUANCE  \
# 0           2003-08-15T00:00:00           2002-08-21T00:00:00
# 1           2006-11-15T00:00:00           2006-04-05T00:00:00
#
#            DATE ISSUED  LICENSE STATUS CHANGE DATE   SSA   LATITUDE  \
# 0  2006-04-11T00:00:00                         NaN  25.0  41.843613
# ...

# %%
test.head(2)
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  1516615-20120216     2132209          280120            1
# 1    69813-20110616     2090759           65043            1
#
#            LEGAL NAME DOING BUSINESS AS NAME                 ADDRESS     CITY  \
# 0      RS HOMES I LLC         RS HOMES I LLC  350 W HUBBARD ST 3 300  CHICAGO
# 1  CSX INTERMODAL INC         CSX INTERMODAL      2101 W 59TH ST 1ST  CHICAGO
#
#   STATE  ZIP CODE  ...  CONDITIONAL APPROVAL  LICENSE TERM START DATE  \
# 0    IL   60610.0  ...                     N      2012-02-16T00:00:00
# 1    IL   60636.0  ...                     N      2011-06-16T00:00:00
#
#   LICENSE TERM EXPIRATION DATE  LICENSE APPROVED FOR ISSUANCE  \
# 0          2014-02-15T00:00:00            2012-01-19T00:00:00
# 1          2013-06-15T00:00:00            2012-11-02T00:00:00
#
#            DATE ISSUED LICENSE STATUS CHANGE DATE  SSA   LATITUDE  LONGITUDE  \
# ...

# %%
submissions= pd.DataFrame({'ID':test.ID})

# %%
submissions.head(2)
# Out:
#                  ID
# 0  1516615-20120216
# 1    69813-20110616

# %%
print(train.shape)
print(test.shape)
# Out:
# (85895, 32)
# (57239, 31)

# %%
train.describe()
# Out:
#          LICENSE ID  ACCOUNT NUMBER   SITE NUMBER          WARD      PRECINCT  \
# count  8.589500e+04    85895.000000  85895.000000  36194.000000  29194.000000
# mean   1.751303e+06   196695.421701      2.556028     28.528927     54.632973
# std    3.358780e+05   126819.343760      8.655706     13.921710    163.174955
# min    3.079300e+04       10.000000      1.000000      1.000000      1.000000
# 25%    1.469024e+06    54615.000000      1.000000     17.000000     12.000000
# 50%    1.778754e+06   248313.000000      1.000000     30.000000     26.000000
# 75%    2.067578e+06   300243.500000      2.000000     42.000000     41.000000
# max    2.456551e+06   397444.000000    417.000000     50.000000    999.000000
#
#        POLICE DISTRICT  LICENSE CODE  LICENSE NUMBER          SSA  \
# count     31883.000000  85895.000000    8.589400e+04  9449.000000
# mean         13.529812   1111.736620    1.228151e+06    29.152080
# std           7.275874    250.020872    7.431487e+05    17.419898
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85895 entries, 0 to 85894
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 85895 non-null  object
#  1   LICENSE ID                         85895 non-null  int64
#  2   ACCOUNT NUMBER                     85895 non-null  int64
#  3   SITE NUMBER                        85895 non-null  int64
#  4   LEGAL NAME                         85895 non-null  object
#  5   DOING BUSINESS AS NAME             85894 non-null  object
#  6   ADDRESS                            85895 non-null  object
#  7   CITY                               85895 non-null  object
#  8   STATE                              85895 non-null  object
#  9   ZIP CODE                           85864 non-null  object
#  10  WARD                               36194 non-null  float64
# ...

# %%
train.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# LICENSE ID         -0.280211
# ACCOUNT NUMBER     -0.269865
# SITE NUMBER        12.149178
# WARD               -0.382168
# PRECINCT            5.555225
# POLICE DISTRICT     1.051476
# LICENSE CODE        7.442521
# LICENSE NUMBER     -0.652406
# SSA                 0.231884
# LATITUDE           -0.670184
# LONGITUDE          -0.462313
# dtype: float64

# %%
train.isnull().sum()
# Out:
# ID                                       0
# LICENSE ID                               0
# ACCOUNT NUMBER                           0
# SITE NUMBER                              0
# LEGAL NAME                               0
# DOING BUSINESS AS NAME                   1
# ADDRESS                                  0
# CITY                                     0
# STATE                                    0
# ZIP CODE                                31
# WARD                                 49701
# PRECINCT                             56701
# WARD PRECINCT                        49700
# POLICE DISTRICT                      54012
# LICENSE CODE                             0
# LICENSE DESCRIPTION                      0
# LICENSE NUMBER                           1
# APPLICATION TYPE                         0
# APPLICATION CREATED DATE             64660
# APPLICATION REQUIREMENTS COMPLETE      214
# PAYMENT DATE                          1289
# CONDITIONAL APPROVAL                     0
# ...

# %%
test.isnull().sum()
# Out:
# ID                                       0
# LICENSE ID                               0
# ACCOUNT NUMBER                           0
# SITE NUMBER                              0
# LEGAL NAME                               0
# DOING BUSINESS AS NAME                   2
# ADDRESS                                  0
# CITY                                     0
# STATE                                    0
# ZIP CODE                                12
# WARD                                   626
# PRECINCT                              1578
# WARD PRECINCT                          616
# POLICE DISTRICT                       1475
# LICENSE CODE                             0
# LICENSE DESCRIPTION                      0
# LICENSE NUMBER                           0
# APPLICATION TYPE                         0
# APPLICATION CREATED DATE             44587
# APPLICATION REQUIREMENTS COMPLETE      428
# PAYMENT DATE                          1051
# CONDITIONAL APPROVAL                     0
# ...

# %%
train.nunique()
# Out:
# ID                                   85895
# LICENSE ID                           85895
# ACCOUNT NUMBER                       38897
# SITE NUMBER                            177
# LEGAL NAME                           38744
# DOING BUSINESS AS NAME               41686
# ADDRESS                              42146
# CITY                                  1223
# STATE                                   54
# ZIP CODE                              2456
# WARD                                    50
# PRECINCT                                76
# WARD PRECINCT                         2383
# POLICE DISTRICT                         28
# LICENSE CODE                           106
# LICENSE DESCRIPTION                    106
# LICENSE NUMBER                       49768
# APPLICATION TYPE                         5
# APPLICATION CREATED DATE              2899
# APPLICATION REQUIREMENTS COMPLETE     3078
# PAYMENT DATE                          4356
# CONDITIONAL APPROVAL                     2
# ...

# %%
train[train.WARD.notnull()].WARD.unique()
# Out:
# array([22., 33., 25., 35.,  2., 18., 17., 45., 39., 42., 30., 34., 43.,
#        49., 10., 32.,  1., 31., 27., 20., 11., 40., 12.,  7.,  6., 28.,
#        44., 48., 29., 37., 46., 47.,  3., 38., 14., 13., 16.,  5., 15.,
#        21.,  8., 36.,  4., 23., 26., 41., 24., 50., 19.,  9.])

# %%
import seaborn as sns
sns.countplot(train["LICENSE STATUS"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train["LICENSE STATUS"].value_counts()
# Out:
# AAI    55400
# AAC    30200
# REV      290
# REA        3
# INQ        2
# Name: LICENSE STATUS, dtype: int64

# %%
# train.corr()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(train.corr(),annot=True)
plt.show()

# %%
train.columns.size
# Out:
# 32

# %%
num_cols=[""]
cat_cols=[""]

# %%
train["LOCATION"][0]
# Out:
# '{\'latitude\': \'41.843612879431845\', \'longitude\': \'-87.71461847216574\', \'needs_recoding\': False, \'human_address\': \'{"address":"","city":"","state":"","zip":""}\'}'

# %%
train["APPLICATION REQUIREMENTS COMPLETE"].value_counts()
# Out:
# 2003-12-15T00:00:00    4803
# 2006-12-20T00:00:00    4281
# 2005-12-21T00:00:00    4194
# 2004-12-20T00:00:00    4168
# 2002-12-17T00:00:00    3751
#                        ...
# 2001-12-14T00:00:00       1
# 2005-11-01T00:00:00       1
# 2012-01-29T00:00:00       1
# 2000-11-27T00:00:00       1
# 2001-11-08T00:00:00       1
# Name: APPLICATION REQUIREMENTS COMPLETE, Length: 3078, dtype: int64

# %%
train["PAYMENT DATE"].value_counts()
# Out:
# 2006-01-23T00:00:00    353
# 2004-01-20T00:00:00    345
# 2005-01-19T00:00:00    329
# 2004-01-12T00:00:00    280
# 2006-01-30T00:00:00    277
#                       ...
# 2001-10-09T00:00:00      1
# 2014-01-03T00:00:00      1
# 2013-12-29T00:00:00      1
# 2010-08-07T00:00:00      1
# 2013-01-25T00:00:00      1
# Name: PAYMENT DATE, Length: 4356, dtype: int64

# %% [markdown]
# #Datapreprocessing

# %%
col_list=['APPLICATION CREATED DATE','SSA','LICENSE ID','ADDRESS','LOCATION','ID']

# %%
train.drop(columns=col_list,axis=1,inplace=True,)
test.drop(columns=col_list,axis=1,inplace=True)

# %%
print(train.columns.size)
print(test.columns.size)
# Out:
# 26
# 25

# %%
train.head(2)
# Out:
#    ACCOUNT NUMBER  SITE NUMBER           LEGAL NAME DOING BUSINESS AS NAME  \
# 0           32811            1         CARMEN CAHUE  CLAUDIA'S BRIDAL SHOP
# 1          262311           29  ISLA TROPICAL, INC.          ISLA TROPICAL
#
#       CITY STATE ZIP CODE  WARD  PRECINCT WARD PRECINCT  ...  \
# 0  CHICAGO    IL  60623.0  22.0      28.0         22-28  ...
# 1  CHICAGO    IL    60618  33.0      23.0         33-23  ...
#
#           PAYMENT DATE  CONDITIONAL APPROVAL LICENSE TERM START DATE  \
# 0  2002-08-21T00:00:00                     N     2002-08-16T00:00:00
# 1  2005-11-03T00:00:00                     N     2005-11-16T00:00:00
#
#    LICENSE TERM EXPIRATION DATE LICENSE APPROVED FOR ISSUANCE  \
# 0           2003-08-15T00:00:00           2002-08-21T00:00:00
# 1           2006-11-15T00:00:00           2006-04-05T00:00:00
#
#            DATE ISSUED LICENSE STATUS CHANGE DATE   LATITUDE  LONGITUDE  \
# 0  2006-04-11T00:00:00                        NaN  41.843613 -87.714618
# ...

# %%
def conv_date(date_col):
  for i in date_col:
    train[i]= pd.to_datetime(train[i])
    test[i]= pd.to_datetime(test[i])

# %%
date_col=["DATE ISSUED","LICENSE TERM START DATE","LICENSE STATUS CHANGE DATE","LICENSE TERM EXPIRATION DATE","PAYMENT DATE","APPLICATION REQUIREMENTS COMPLETE","LICENSE APPROVED FOR ISSUANCE"]

# %%
conv_date(date_col)

# %%
train[date_col]
# Out:
#       DATE ISSUED LICENSE TERM START DATE LICENSE STATUS CHANGE DATE  \
# 0      2006-04-11              2002-08-16                        NaT
# 1      2006-06-12              2005-11-16                 2006-06-15
# 2      2009-07-22              2009-07-22                        NaT
# 3      2004-02-11              2004-02-11                        NaT
# 4      2008-06-05              2008-05-16                        NaT
# ...           ...                     ...                        ...
# 85890  2012-05-08              2012-05-16                 2012-12-29
# 85891  2007-05-22              2007-05-22                        NaT
# 85892  2009-12-08              2009-01-16                        NaT
# 85893  2011-10-11              2011-10-16                 2012-05-08
# 85894  2004-02-09              2004-02-16                 2005-01-07
#
#       LICENSE TERM EXPIRATION DATE PAYMENT DATE  \
# 0                       2003-08-15   2002-08-21
# ...

# %%
train["DATE ISSUED"][0].year
# Out:
# 2006

# %%
def year(colname,datecol):
  train[colname]=train[datecol].apply(lambda x:x.year)
  test[colname]= test[datecol].apply(lambda x:x.year)

# %%
year("LICENSE STATUS CHANGE YEAR","LICENSE STATUS CHANGE DATE")

# %%
train["LICENSE STATUS CHANGE YEAR"]
# Out:
# 0           NaN
# 1        2006.0
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 85890    2012.0
# 85891       NaN
# 85892       NaN
# 85893    2012.0
# 85894    2005.0
# Name: LICENSE STATUS CHANGE YEAR, Length: 85895, dtype: float64

# %%
date_col
# Out:
# ['DATE ISSUED',
#  'LICENSE TERM START DATE',
#  'LICENSE STATUS CHANGE DATE',
#  'LICENSE TERM EXPIRATION DATE',
#  'PAYMENT DATE',
#  'APPLICATION REQUIREMENTS COMPLETE',
#  'LICENSE APPROVED FOR ISSUANCE']

# %%
year("LICENSE STATUS CHANGE YEAR","LICENSE STATUS CHANGE DATE")
year("DATE ISSUED YEAR","DATE ISSUED")
year("LICENSE APPROVED FOR ISSUANCE YEAR","LICENSE APPROVED FOR ISSUANCE")
year("APPLICATION REQUIREMENTS COMPLETE YEAR","APPLICATION REQUIREMENTS COMPLETE")
year("LICENSE TERM EXPIRATION YEAR","LICENSE TERM EXPIRATION DATE")
year("LICENSE TERM START YEAR","LICENSE TERM START DATE")

# %%
print(train["LICENSE TERM EXPIRATION YEAR"].isnull().sum())
print(train["LICENSE TERM START YEAR"].isnull().sum())
# Out:
# 18
# 228

# %%
train[train["LICENSE TERM EXPIRATION YEAR"].isnull()]["LICENSE TERM EXPIRATION YEAR"]
# Out:
# 138     NaN
# 184     NaN
# 7121    NaN
# 7439    NaN
# 13232   NaN
# 27046   NaN
# 31510   NaN
# 37317   NaN
# 45017   NaN
# 47519   NaN
# 48394   NaN
# 52689   NaN
# 59161   NaN
# 62261   NaN
# 63482   NaN
# 70379   NaN
# 73386   NaN
# 77278   NaN
# Name: LICENSE TERM EXPIRATION YEAR, dtype: float64

# %%
def fill_mean_year(col_list):
  for i in col_list:
    train[i]= train[i].fillna(round(train[i].mean()))
    test[i]=test[i].fillna(round(test[i].mean()))

# %%
fill_year_list=["LICENSE STATUS CHANGE YEAR","DATE ISSUED YEAR","LICENSE APPROVED FOR ISSUANCE YEAR",
                "APPLICATION REQUIREMENTS COMPLETE YEAR","LICENSE TERM EXPIRATION YEAR","LICENSE TERM START YEAR"
]

fill_mean_year(fill_year_list)

# %%
print(train["LICENSE TERM EXPIRATION YEAR"].isnull().sum())
print(train["LICENSE TERM START YEAR"].isnull().sum())
# Out:
# 0
# 0

# %%
# import numpy as np
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# x=train.loc[:,"LICENSE TERM EXPIRATION YEAR"].values.reshape(-1, 1) 
# # print(x)
# imputer=imputer.fit(x)
# x=imputer.transform(x)
# count=0
# for i in np.isnan(x):
#   if(i==True):
#     count+=1
# # np.count_nonzero(np.isnan(x))
# print(count)

# %%
train["LICENSE VALID"]=train["LICENSE TERM EXPIRATION YEAR"]-train["LICENSE TERM START YEAR"]
test["LICENSE VALID"]= test["LICENSE TERM EXPIRATION YEAR"]-train["LICENSE TERM START YEAR"]

# %%
train.columns
# Out:
# Index(['ACCOUNT NUMBER', 'SITE NUMBER', 'LEGAL NAME', 'DOING BUSINESS AS NAME',
#        'CITY', 'STATE', 'ZIP CODE', 'WARD', 'PRECINCT', 'WARD PRECINCT',
#        'POLICE DISTRICT', 'LICENSE CODE', 'LICENSE DESCRIPTION',
#        'LICENSE NUMBER', 'APPLICATION TYPE',
#        'APPLICATION REQUIREMENTS COMPLETE', 'PAYMENT DATE',
#        'CONDITIONAL APPROVAL', 'LICENSE TERM START DATE',
#        'LICENSE TERM EXPIRATION DATE', 'LICENSE APPROVED FOR ISSUANCE',
#        'DATE ISSUED', 'LICENSE STATUS CHANGE DATE', 'LATITUDE', 'LONGITUDE',
#        'LICENSE STATUS', 'LICENSE STATUS CHANGE YEAR', 'DATE ISSUED YEAR',
#        'LICENSE APPROVED FOR ISSUANCE YEAR',
#        'APPLICATION REQUIREMENTS COMPLETE YEAR',
#        'LICENSE TERM EXPIRATION YEAR', 'LICENSE TERM START YEAR',
#        'LICENSE VALID'],
#       dtype='object')

# %%
drop_col=["LICENSE TERM START YEAR",'DATE ISSUED',
 'LICENSE TERM START DATE',
 'LICENSE STATUS CHANGE DATE',
 'LICENSE TERM EXPIRATION DATE',
 'APPLICATION REQUIREMENTS COMPLETE',
 'LICENSE APPROVED FOR ISSUANCE',
 "LICENSE TERM EXPIRATION YEAR",
 ]  

train.drop(columns=drop_col,axis=1,inplace=True)
test.drop(columns=drop_col,axis=1,inplace=True)

# %%
train.columns.size
# Out:
# 25

# %%
train["LICENSE VALID"].unique()
# Out:
# array([   1.,    2.,    0.,    3.,    5.,   -1.,   -2.,    4.,   -5.,
#          -4.,   -6.,   -3.,  -10.,   -9.,   -8.,    7.,   -7.,  -12.,
#           6.,  -11., -101.])

# %%
train["LICENSE VALID"]=train["LICENSE VALID"].apply(lambda x: abs(x))
test["LICENSE VALID"]=test["LICENSE VALID"].apply(lambda x: abs(x))

# %%
train["LICENSE VALID"].unique()
# Out:
# array([  1.,   2.,   0.,   3.,   5.,   4.,   6.,  10.,   9.,   8.,   7.,
#         12.,  11., 101.])

# %%
print(train["LEGAL NAME"].nunique())
test["LEGAL NAME"].nunique()
# Out:
# 38744
# 36523

# %%
train["LEGAL NAME"].isnull().sum()
# Out:
# 0

# %%
train["LEGAL NAME"]
# Out:
# 0                          CARMEN CAHUE
# 1                   ISLA TROPICAL, INC.
# 2                        DJS REMODELING
# 3              ALL-BRY CONSTRUCTION CO.
# 4          MCDONOUGH MECHANICAL SERVICE
#                       ...
# 85890             UNITED PARCEL SERVICE
# 85891    EXPRESS BOARD UP SERVICE, INC.
# 85892                  ARAMARK SMMS LLC
# 85893     GENERAL NUTRITION CORPORATION
# 85894                 JUAN CARLOS ERAZO
# Name: LEGAL NAME, Length: 85895, dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85895 entries, 0 to 85894
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ACCOUNT NUMBER                          85895 non-null  int64
#  1   SITE NUMBER                             85895 non-null  int64
#  2   LEGAL NAME                              85895 non-null  object
#  3   DOING BUSINESS AS NAME                  85894 non-null  object
#  4   CITY                                    85895 non-null  object
#  5   STATE                                   85895 non-null  object
#  6   ZIP CODE                                85864 non-null  object
#  7   WARD                                    36194 non-null  float64
#  8   PRECINCT                                29194 non-null  float64
#  9   WARD PRECINCT                           36195 non-null  object
# ...

# %%
train['DOING BUSINESS AS NAME'].apply(lambda x: str(x).upper())
# Out:
# 0                 CLAUDIA'S BRIDAL SHOP
# 1                         ISLA TROPICAL
# 2                  DJS REMODELING, INC.
# 3              ALL-BRY CONSTRUCTION CO.
# 4          MCDONOUGH MECHANICAL SERVICE
#                       ...
# 85890             UNITED PARCEL SERVICE
# 85891    EXPRESS BOARD UP SERVICE, INC.
# 85892         ARAMARK FACILITY SERVICES
# 85893     GENERAL NUTRITION CENTER # 61
# 85894           CASA DE JUAN RESTAURANT
# Name: DOING BUSINESS AS NAME, Length: 85895, dtype: object

# %%
train['LEGAL NAME'].apply(lambda x: x.upper())
train['DOING BUSINESS AS NAME'].apply(lambda x: str(x).upper())
test['LEGAL NAME'].apply(lambda x: x.upper())
test['DOING BUSINESS AS NAME'].apply(lambda x: str(x).upper())
train.head()
# Out:
#    ACCOUNT NUMBER  SITE NUMBER                    LEGAL NAME  \
# 0           32811            1                  CARMEN CAHUE
# 1          262311           29           ISLA TROPICAL, INC.
# 2          345008            1                DJS REMODELING
# 3          273121            1      ALL-BRY CONSTRUCTION CO.
# 4          213785            1  MCDONOUGH MECHANICAL SERVICE
#
#          DOING BUSINESS AS NAME      CITY STATE ZIP CODE  WARD  PRECINCT  \
# 0         CLAUDIA'S BRIDAL SHOP   CHICAGO    IL  60623.0  22.0      28.0
# 1                 ISLA TROPICAL   CHICAGO    IL    60618  33.0      23.0
# 2          DJS REMODELING, INC.  HIGHLAND    IL    60035   NaN       NaN
# 3      ALL-BRY CONSTRUCTION CO.    LEMONT    IL    60439   NaN       NaN
# 4  MCDONOUGH MECHANICAL SERVICE  WAUKEGAN    IL    60087   NaN       NaN
#
#   WARD PRECINCT  ...  PAYMENT DATE  CONDITIONAL APPROVAL   LATITUDE  \
# 0         22-28  ...    2002-08-21                     N  41.843613
# ...

# %%
import numpy as np

# %%
def fill_none(fill_none_list):
    for i in fill_none_list:
        train[i] = train[i].fillna('None')
        test[i] = test[i].fillna('None')
fill_none_list = ['LEGAL NAME', 'DOING BUSINESS AS NAME']
fill_none(fill_none_list)

# %%
train['LEGAL NAME'] = train['LEGAL NAME'].str.replace('.', '')
train['DOING BUSINESS AS NAME'] = train['DOING BUSINESS AS NAME'].str.replace('.', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# train['COMP TYPE'] = 'others'
# test["COMP TYPE"]='others'

# %%
def test_company_type(comp_type_in,comp_type):
  test['COMP TYPE'] = np.where(test['LEGAL NAME'].str.contains(comp_type_in),comp_type,test['COMP TYPE'])
  test['COMP TYPE'] = np.where(test['DOING BUSINESS AS NAME'].str.contains(comp_type_in),comp_type,test['COMP TYPE'])  

test["COMP TYPE"]="others"
test_company_type('INC','INC')
test_company_type('INCORPORATED','INC')
test_company_type('CORPORATION','CORP')
test_company_type('CORP','CORP')
test_company_type('CO','CORP')
test_company_type('LTD','LTD')
test_company_type('LIMITED','LTD')
test_company_type('LLC','LLC')

# %%
def train_company_type(comp_type_in,comp_type):
  train['COMP TYPE'] = np.where(train['LEGAL NAME'].str.contains(comp_type_in),comp_type,train['COMP TYPE'])
  train['COMP TYPE'] = np.where(train['DOING BUSINESS AS NAME'].str.contains(comp_type_in),comp_type,train['COMP TYPE'])  

train["COMP TYPE"]="others"
train_company_type('INC','INC')
train_company_type('INCORPORATED','INC')
train_company_type('CORPORATION','CORP')
train_company_type('CORP','CORP')
train_company_type('CO','CORP')
train_company_type('LTD','LTD')
train_company_type('LIMITED','LTD')
train_company_type('LLC','LLC')

# %%
test["COMP TYPE"].value_counts()
# Out:
# INC       19604
# others    17989
# CORP      12398
# LLC        5756
# LTD        1492
# Name: COMP TYPE, dtype: int64

# %%
train['COMP TYPE'].value_counts()
# Out:
# others    27020
# CORP      26364
# INC       24447
# LLC        6487
# LTD        1577
# Name: COMP TYPE, dtype: int64

# %%
sns.countplot(train['COMP TYPE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
list1=["LEGAL NAME","DOING BUSINESS AS NAME"]
train.drop(list1, axis=1,inplace=True) 
test.drop(list1, axis=1,inplace=True)

# %%
train["LICENSE DESCRIPTION"].nunique()
# Out:
# 106

# %%
pd.set_option('display.max_rows',150)
train["LICENSE DESCRIPTION"].value_counts()
# Out:
# Limited Business License                                        50078
# Home Repair                                                     10633
# Peddler, non-food                                                2812
# Home Occupation                                                  2809
# Retail Food Establishment                                        2321
# Massage Therapist                                                1952
# Street Performer                                                 1889
# Scavenger, Private                                               1549
# Hazardous Materials                                              1126
# Residential Real Estate Developer                                1087
# Motor Vehicle Repair : Engine Only (Class II)                     931
# Automatic Amusement Device Operator                               773
# Peddler, food (fruits and vegtables only)                         582
# ...

# %%
def license_desc(description_name,new_description):
  train['LICENSE DESCRIPTION'] = train['LICENSE DESCRIPTION'].replace(description_name, new_description)
  test['LICENSE DESCRIPTION'] = test['LICENSE DESCRIPTION'].replace(description_name, new_description)

# %%
license_desc('Peddler, non-food, special', 'Peddler')
license_desc('Peddler, food (fruits and vegtables only)', 'Peddler')
license_desc('Peddler,food - (fruits and vegetables only) - special', 'Peddler')
license_desc('Motor Vehicle Repair : Engine Only (Class II)', 'Motor Vehicle Repair')
license_desc('Motor Vehicle Repair: Engine/Body(Class III)', 'Motor Vehicle Repair')
license_desc('Motor Vehicle Repair; Specialty(Class I)', 'Motor Vehicle Repair')
license_desc('Day Care Center Under 2 Years', 'Day Care Center')
license_desc('Day Care Center 2 - 6 Years', 'Day Care Center')
license_desc('Day Care Center Under 2 and 2 - 6 Years', 'Day Care Center')
license_desc('Repossessor Class A', 'Repossessor')
license_desc('Repossessor Class B', 'Repossessor')
license_desc('Repossessor Class B Employee', 'Repossessor')
license_desc('Expediter - Class B', 'Expediter')
license_desc('Expediter - Class A', 'Expediter')
license_desc('Expediter - Class B Employee', 'Expediter')
license_desc('Itinerant Merchant, Class II', 'Itinerant Merchant')
license_desc('Itinerant Merchant, Class I', 'Itinerant Merchant')
# license_desc()

# %%
# pd.set_option('display.max_rows',150)
train["LICENSE DESCRIPTION"].value_counts()
# Out:
# Limited Business License                                        50078
# Home Repair                                                     10633
# Peddler, non-food                                                2812
# Home Occupation                                                  2809
# Retail Food Establishment                                        2321
# Massage Therapist                                                1952
# Street Performer                                                 1889
# Scavenger, Private                                               1549
# Motor Vehicle Repair                                             1534
# Hazardous Materials                                              1126
# Residential Real Estate Developer                                1087
# Peddler                                                           970
# Automatic Amusement Device Operator                               773
# ...

# %%
license_desc('Tire Facilty Class I (100 - 1,000 Tires)', 'Tire Facilty')
license_desc('Tire Facility Class II (1,001 - 5,000 Tires)', 'Tire Facilty')
license_desc('Tire Facility Class III (5,001 - More Tires)', 'Tire Facilty')
license_desc('Single Room Occupancy Class II','Single Room Occupancy')
license_desc('Single Room Occupancy Class I','Single Room Occupancy')
# license_desc()

# %%
x=train["LICENSE DESCRIPTION"].value_counts()<=15
y=x[x].index

# %%
def license_desc_list(description_name_list):
  for i in description_name_list:
    # print(i)
    train['LICENSE DESCRIPTION'] = train['LICENSE DESCRIPTION'].replace(i, 'others')
    test['LICENSE DESCRIPTION'] = test['LICENSE DESCRIPTION'].replace(i,'others')

# %%
license_desc_list(y)

# %%
train["LICENSE DESCRIPTION"].value_counts()
# Out:
# Limited Business License                            50078
# Home Repair                                         10633
# Peddler, non-food                                    2812
# Home Occupation                                      2809
# Retail Food Establishment                            2321
# Massage Therapist                                    1952
# Street Performer                                     1889
# Scavenger, Private                                   1549
# Motor Vehicle Repair                                 1534
# Hazardous Materials                                  1126
# Residential Real Estate Developer                    1087
# Peddler                                               970
# Automatic Amusement Device Operator                   773
# Mobile Food Dispenser                                 525
# Day Care Center                                       522
# Manufacturing Establishments                          458
# ...

# %%
train.isnull().sum()
# Out:
# ACCOUNT NUMBER                                0
# SITE NUMBER                                   0
# CITY                                          0
# STATE                                         0
# ZIP CODE                                     31
# WARD                                      49701
# PRECINCT                                  56701
# WARD PRECINCT                             49700
# POLICE DISTRICT                           54012
# LICENSE CODE                                  0
# LICENSE DESCRIPTION                           0
# LICENSE NUMBER                                1
# APPLICATION TYPE                              0
# PAYMENT DATE                               1289
# CONDITIONAL APPROVAL                          0
# LATITUDE                                  47246
# LONGITUDE                                 47246
# LICENSE STATUS                                0
# LICENSE STATUS CHANGE YEAR                    0
# DATE ISSUED YEAR                              0
# ...

# %%
def fill_null(fill_null_list):
    for i in fill_null_list:
        train[i] = train[i].fillna(0)
        test[i] = test[i].fillna(0)

# %%
train[train["LICENSE NUMBER"].isnull()]["LICENSE STATUS"]
# Out:
# 28189    AAC
# Name: LICENSE STATUS, dtype: object

# %%
train=train.dropna(subset = ['LICENSE NUMBER'])

# %%
train["LICENSE NUMBER"].isnull().sum()
# Out:
# 0

# %%
fill_null_list = ['WARD', 'PRECINCT', 'POLICE DISTRICT', 'WARD PRECINCT']
fill_null(fill_null_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.isnull().sum()
# Out:
# ACCOUNT NUMBER                                0
# SITE NUMBER                                   0
# CITY                                          0
# STATE                                         0
# ZIP CODE                                     31
# WARD                                          0
# PRECINCT                                      0
# WARD PRECINCT                                 0
# POLICE DISTRICT                               0
# LICENSE CODE                                  0
# LICENSE DESCRIPTION                           0
# LICENSE NUMBER                                0
# APPLICATION TYPE                              0
# PAYMENT DATE                               1289
# CONDITIONAL APPROVAL                          0
# LATITUDE                                  47245
# LONGITUDE                                 47245
# LICENSE STATUS                                0
# LICENSE STATUS CHANGE YEAR                    0
# DATE ISSUED YEAR                              0
# ...

# %%
print(train["WARD PRECINCT"].nunique())
train["WARD PRECINCT"].unique()
# Out:
# 2384
# array(['22-28', '33-23', 0, ..., '42-57', '37-9', '17-37'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
train["WARD PRECINCT"] = encoder.fit_transform(train["WARD PRECINCT"].astype(str))
test["WARD PRECINCT"] = encoder.fit_transform(test["WARD PRECINCT"].astype(str))

# %%
print(train["ZIP CODE"].nunique())
train["ZIP CODE"].unique()
# Out:
# 2456
# array(['60623.0', '60618', '60035', ..., 60511.0, 30076.0, 61115.0],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
train["ZIP CODE"] = encoder.fit_transform(train["ZIP CODE"].astype(str))
test["ZIP CODE"] = encoder.fit_transform(test["ZIP CODE"].astype(str))

# %%
def fill_mean(fill_mean_list):
    for i in fill_mean_list:
        train[i] = train[i].fillna(train[i].mean())
        test[i] = test[i].fillna(train[i].mean())

fill_mean_list = ['LATITUDE', 'LONGITUDE']
fill_mean(fill_mean_list)

# %%
year("PAYMENT YEAR","PAYMENT DATE")
fill_mean_year(["PAYMENT YEAR"])

# %%
train.isnull().sum()
# Out:
# ACCOUNT NUMBER                               0
# SITE NUMBER                                  0
# CITY                                         0
# STATE                                        0
# ZIP CODE                                     0
# WARD                                         0
# PRECINCT                                     0
# WARD PRECINCT                                0
# POLICE DISTRICT                              0
# LICENSE CODE                                 0
# LICENSE DESCRIPTION                          0
# LICENSE NUMBER                               0
# APPLICATION TYPE                             0
# PAYMENT DATE                              1289
# CONDITIONAL APPROVAL                         0
# LATITUDE                                     0
# LONGITUDE                                    0
# LICENSE STATUS                               0
# LICENSE STATUS CHANGE YEAR                   0
# DATE ISSUED YEAR                             0
# ...

# %%
test.isnull().sum()
# Out:
# ACCOUNT NUMBER                               0
# SITE NUMBER                                  0
# CITY                                         0
# STATE                                        0
# ZIP CODE                                     0
# WARD                                         0
# PRECINCT                                     0
# WARD PRECINCT                                0
# POLICE DISTRICT                              0
# LICENSE CODE                                 0
# LICENSE DESCRIPTION                          0
# LICENSE NUMBER                               0
# APPLICATION TYPE                             0
# PAYMENT DATE                              1051
# CONDITIONAL APPROVAL                         0
# LATITUDE                                     0
# LONGITUDE                                    0
# LICENSE STATUS CHANGE YEAR                   0
# DATE ISSUED YEAR                             0
# LICENSE APPROVED FOR ISSUANCE YEAR           0
# ...

# %%
train=train.drop(columns="PAYMENT DATE")
test=test.drop(columns="PAYMENT DATE")

# %%
test.isnull().sum()
# Out:
# ACCOUNT NUMBER                            0
# SITE NUMBER                               0
# CITY                                      0
# STATE                                     0
# ZIP CODE                                  0
# WARD                                      0
# PRECINCT                                  0
# WARD PRECINCT                             0
# POLICE DISTRICT                           0
# LICENSE CODE                              0
# LICENSE DESCRIPTION                       0
# LICENSE NUMBER                            0
# APPLICATION TYPE                          0
# CONDITIONAL APPROVAL                      0
# LATITUDE                                  0
# LONGITUDE                                 0
# LICENSE STATUS CHANGE YEAR                0
# DATE ISSUED YEAR                          0
# LICENSE APPROVED FOR ISSUANCE YEAR        0
# APPLICATION REQUIREMENTS COMPLETE YEAR    0
# LICENSE VALID                             0
# ...

# %%
pd.set_option('display.max_columns', None)
train.head()
# Out:
#    ACCOUNT NUMBER  SITE NUMBER      CITY STATE  ZIP CODE  WARD  PRECINCT  \
# 0           32811            1   CHICAGO    IL      1559  22.0      28.0
# 1          262311           29   CHICAGO    IL      1548  33.0      23.0
# 2          345008            1  HIGHLAND    IL      1025   0.0       0.0
# 3          273121            1    LEMONT    IL      1329   0.0       0.0
# 4          213785            1  WAUKEGAN    IL      1095   0.0       0.0
#
#    WARD PRECINCT  POLICE DISTRICT  LICENSE CODE       LICENSE DESCRIPTION  \
# 0            689             10.0          1010  Limited Business License
# 1           1230             17.0          1315     Mobile Food Dispenser
# 2              1              0.0          1011               Home Repair
# 3              1              0.0          1010  Limited Business License
# 4              1              0.0          1010  Limited Business License
#
#    LICENSE NUMBER APPLICATION TYPE CONDITIONAL APPROVAL   LATITUDE  LONGITUDE  \
# ...

# %%
train["LICENSE STATUS"].value_counts()
# Out:
# AAI    55400
# AAC    30199
# REV      290
# REA        3
# INQ        2
# Name: LICENSE STATUS, dtype: int64

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()

# le.fit(train.loc[:,"LICENSE STATUS"].values)

# %%
# train.loc[:,"LICENSE STATUS"].values

# %%
# le.classes_

# %%
train["LICENSE STATUS"] = train["LICENSE STATUS"].replace('AAI', 0)
train["LICENSE STATUS"] = train["LICENSE STATUS"].replace('AAC', 1)
train["LICENSE STATUS"] = train["LICENSE STATUS"].replace('REV', 2)
train["LICENSE STATUS"] = train["LICENSE STATUS"].replace('REA', 3)
train["LICENSE STATUS"] = train["LICENSE STATUS"].replace('INQ', 4)

# %%
le = LabelEncoder()
train["WARD PRECINCT"] = le.fit_transform(train["WARD PRECINCT"].astype(str))
test["WARD PRECINCT"] = le.fit_transform(test["WARD PRECINCT"].astype(str))

# %%
le = LabelEncoder()
train["ZIP CODE"] = le.fit_transform(train["ZIP CODE"].astype(str))
test["ZIP CODE"] = le.fit_transform(test["ZIP CODE"].astype(str))

# %%
train.head()
# Out:
#    ACCOUNT NUMBER  SITE NUMBER      CITY STATE  ZIP CODE  WARD  PRECINCT  \
# 0           32811            1   CHICAGO    IL       623  22.0      28.0
# 1          262311           29   CHICAGO    IL       611  33.0      23.0
# 2          345008            1  HIGHLAND    IL        31   0.0       0.0
# 3          273121            1    LEMONT    IL       368   0.0       0.0
# 4          213785            1  WAUKEGAN    IL       108   0.0       0.0
#
#    WARD PRECINCT  POLICE DISTRICT  LICENSE CODE       LICENSE DESCRIPTION  \
# 0           2039             10.0          1010  Limited Business License
# 1            259             17.0          1315     Mobile Food Dispenser
# 2              1              0.0          1011               Home Repair
# 3              1              0.0          1010  Limited Business License
# 4              1              0.0          1010  Limited Business License
#
#    LICENSE NUMBER APPLICATION TYPE CONDITIONAL APPROVAL   LATITUDE  LONGITUDE  \
# ...

# %%
def create_dummies(df):
    for i in df.columns:
        if df[i].dtypes=='object':
            print(i,'encoded')
            mask = ~df[i].isnull()
            label_encoder = LabelEncoder() 
            try:
                df[i][mask] = label_encoder.fit_transform(df[i][mask])
                df[i] = df[i].astype(int)
            except Exception as e:
                print(e)
    return df

# %%
train = create_dummies(train)
# Out:
# CITY encoded
# STATE encoded
# LICENSE DESCRIPTION encoded
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# APPLICATION TYPE encoded
# CONDITIONAL APPROVAL encoded
# COMP TYPE encoded

# %%
train.head()
# Out:
#    ACCOUNT NUMBER  SITE NUMBER  CITY  STATE  ZIP CODE  WARD  PRECINCT  \
# 0           32811            1   193     16       623  22.0      28.0
# 1          262311           29   193     16       611  33.0      23.0
# 2          345008            1   466     16        31   0.0       0.0
# 3          273121            1   585     16       368   0.0       0.0
# 4          213785            1  1145     16       108   0.0       0.0
#
#    WARD PRECINCT  POLICE DISTRICT  LICENSE CODE  LICENSE DESCRIPTION  \
# 0           2039             10.0          1010                   28
# 1            259             17.0          1315                   33
# 2              1              0.0          1011                   19
# 3              1              0.0          1010                   28
# 4              1              0.0          1010                   28
#
#    LICENSE NUMBER  APPLICATION TYPE  CONDITIONAL APPROVAL   LATITUDE  \
# ...

# %%
train["LICENSE STATUS"].value_counts()
# Out:
# 0    55400
# 1    30199
# 2      290
# 3        3
# 4        2
# Name: LICENSE STATUS, dtype: int64

# %%
train = train.sample(frac=1)

# Amount of fraud classes in proportion.
fraud_df = train[train['LICENSE STATUS'] == 4]
pending_df = train[train['LICENSE STATUS'] == 3]
accepted_df = train[train['LICENSE STATUS'] == 2]

non_fraud_df = train[train['LICENSE STATUS'] == 1][:290]
non_accepted_df = train[train['LICENSE STATUS'] == 0][:300]

normal_distributed_df = pd.concat([fraud_df, pending_df, accepted_df, non_fraud_df, non_accepted_df, fraud_df,
                                  fraud_df, fraud_df, fraud_df, pending_df, pending_df, fraud_df, pending_df])

# Shuffle dataframe rows
new_df = normal_distributed_df.sample(frac=1, random_state=42)

new_df.head()
# Out:
#        ACCOUNT NUMBER  SITE NUMBER  CITY  STATE  ZIP CODE  WARD  PRECINCT  \
# 82089          366249            1   193     16       664  19.0      20.0
# 73830            5884            1   193     16       620   2.0      50.0
# 20575           12625            1   193     16       658  48.0      24.0
# 35274           85153            1   193     16       616  17.0      22.0
# 18890          346762            1   193     16       673  35.0      60.0
#
#        WARD PRECINCT  POLICE DISTRICT  LICENSE CODE  LICENSE DESCRIPTION  \
# 82089           1780             22.0          1584                   11
# 73830           1877             14.0          1006                   50
# 20575           1096             20.0          1005                   29
# 35274           1666              6.0          1470                   54
# 18890            379             14.0          1524                   31
#
#        LICENSE NUMBER  APPLICATION TYPE  CONDITIONAL APPROVAL   LATITUDE  \
# ...

# %%
plt.title('Distribution of target variable')
sns.countplot(new_df['LICENSE STATUS'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
new_df['LICENSE STATUS'].value_counts()
# Out:
# 0    300
# 2    290
# 1    290
# 4     12
# 3     12
# Name: LICENSE STATUS, dtype: int64

# %%
# Our Subsample
sub_sample_corr = new_df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(sub_sample_corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':20}, cmap='Greens')
plt.title('Subsample Correlation Matrix \n (use for reference)', fontsize=14)
plt.show()

# %%
col_list = ['PAYMENT YEAR', 'APPLICATION REQUIREMENTS COMPLETE YEAR', 'LICENSE APPROVED FOR ISSUANCE YEAR']
new_df = new_df.drop(col_list, axis=1)
test = test.drop(col_list, axis=1)

# %%
sub_sample_corr = new_df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(sub_sample_corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':20}, cmap='Greens')
plt.title('Subsample Correlation Matrix \n (use for reference)', fontsize=14)
plt.show()

# %%
X = new_df.drop('LICENSE STATUS', axis=1)
y = new_df['LICENSE STATUS']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 42)

# %%
from sklearn.metrics import confusion_matrix
def draw_cm(actual, predicted):
    cm = confusion_matrix( actual, predicted)
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels = ["Yes","No"] , yticklabels = ["Yes","No"] )
    plt.ylabel('Predicted')
    plt.xlabel('Actual')
    plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# Create a Logistic regression classifier
logreg = LogisticRegression()

# Train the model using the training sets 
logreg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred = logreg.predict(X_test)
acc_logreg = round( accuracy_score(y_test, y_pred) * 100, 2 )
print( 'Total Accuracy : ', acc_logreg )
# Out:
# Total Accuracy :  47.79

# %%
draw_cm(y_test, y_pred)

# %% [markdown]
# #Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets 
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

acc_nb = round( accuracy_score(y_test, y_pred) * 100, 2 )
print( 'Total Accuracy : ', acc_nb )
# Out:
# Total Accuracy :  60.18

# %% [markdown]
# #Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Create a Decision tree classifier model
clf = DecisionTreeClassifier()

# Hyperparameter Optimization
parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10, 50], 
              'min_samples_split': [2, 3, 50, 100],
              'min_samples_leaf': [1, 5, 8, 10]
             }
# Run the grid search
grid_obj = GridSearchCV(clf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

# Train the model using the training sets 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_train)

feature_importance = pd.DataFrame([X_train.columns, clf.tree_.compute_feature_importances()])
feature_importance = feature_importance.T.sort_values(by = 1, ascending=False)[1:10]


sns.barplot(x=feature_importance[1], y=feature_importance[0])
# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()

y_pred = clf.predict(X_test)

acc_dt = round( accuracy_score(y_test, y_pred) * 100, 2 )
print( 'Total Accuracy : ', acc_dt )
# Out:
# No handles with labels found to put in legend.
# Total Accuracy :  75.66

# %% [markdown]
# #Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest Classifier
rf = RandomForestClassifier()

# Hyperparameter Optimization
parameters = {'n_estimators': [4, 6, 9, 10, 15], 
              'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3, 5, 10], 
              'min_samples_split': [2, 3, 5],
              'min_samples_leaf': [1, 5, 8]
             }

# Run the grid search
grid_obj = GridSearchCV(rf, parameters)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the rf to the best combination of parameters
rf = grid_obj.best_estimator_

# Train the model using the training sets 
rf.fit(X_train,y_train)

feature_imp = pd.Series(rf.feature_importances_,index= X_train.columns).sort_values(ascending=False)
# Creating a bar plot
feature_imp=feature_imp[0:10,]
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()


y_pred = rf.predict(X_test)

acc_rf = round(accuracy_score(y_test, y_pred) * 100 , 2 )
print( 'Total Accuracy : ', acc_rf )
# Out:
# No handles with labels found to put in legend.
# Total Accuracy :  88.94

# %% [markdown]
# #XGBoost

# %%
from xgboost import XGBClassifier, plot_importance
from sklearn.model_selection import GridSearchCV


gbm = XGBClassifier(learning_rate=0.02, n_estimators=1000, objective='multi:softmax', silent=True, nthread=1, num_class=5)


parameters = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.1, 0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 5, 6]
        }


grid_obj = GridSearchCV(gbm, parameters)
grid_obj = grid_obj.fit(X_train, y_train)


gbm = grid_obj.best_estimator_


gbm.fit(X_train, y_train)

y_pred = gbm.predict(X_test)

acc_xgb = round( accuracy_score(y_test, y_pred) * 100 , 2 )
print( 'Total Accuracy : ', acc_xgb )
# Out:
# Total Accuracy :  92.04

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57239 entries, 0 to 57238
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ACCOUNT NUMBER              57239 non-null  int64
#  1   SITE NUMBER                 57239 non-null  int64
#  2   CITY                        57239 non-null  object
#  3   STATE                       57239 non-null  object
#  4   ZIP CODE                    57239 non-null  int64
#  5   WARD                        57239 non-null  float64
#  6   PRECINCT                    57239 non-null  float64
#  7   WARD PRECINCT               57239 non-null  int64
#  8   POLICE DISTRICT             57239 non-null  float64
#  9   LICENSE CODE                57239 non-null  int64
#  10  LICENSE DESCRIPTION         57239 non-null  object
#  11  LICENSE NUMBER              57239 non-null  float64
#  12  APPLICATION TYPE            57239 non-null  object
# ...

# %%
test = create_dummies(test)
# Out:
# CITY encoded
# STATE encoded
# LICENSE DESCRIPTION encoded
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# APPLICATION TYPE encoded
# CONDITIONAL APPROVAL encoded
# COMP TYPE encoded

# %%
my_pred = gbm.predict(test)

# %%
submissions['LICENSE STATUS'] = my_pred

# %%
submissions['LICENSE STATUS'] = submissions['LICENSE STATUS'].replace(0, 'AAI')
submissions['LICENSE STATUS'] = submissions['LICENSE STATUS'].replace(1, 'AAC')
submissions['LICENSE STATUS'] = submissions['LICENSE STATUS'].replace(2, 'REV')
submissions['LICENSE STATUS'] = submissions['LICENSE STATUS'].replace(3, 'REA')
submissions['LICENSE STATUS'] = submissions['LICENSE STATUS'].replace(4, 'INQ')
submissions.to_csv('submission.csv', index=False)
